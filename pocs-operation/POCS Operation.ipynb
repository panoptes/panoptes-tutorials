# %% [markdown]
# An instance of `POCS` can be loaded and run as a simulator, which will then allow you to play with various aspects of of `POCS` and allow all of the different parts of the system.
#
# Any `INFO` level log messages will be displayed in the notebook but you can check `$PANDIR/logs/panoptes.log` for full debug output

# %%
import os 
import sys

# Load the POCS module
from panoptes.pocs.core import POCS
from panoptes.pocs.observatory import Observatory

from panoptes.pocs.mount import create_mount_simulator
from panoptes.pocs.camera import create_camera_simulator
from panoptes.pocs.scheduler import create_scheduler_from_config

from panoptes.pocs.utils.logger import get_logger, LOGGER_INFO
logger = get_logger()
logger.enable('panoptes')

# %%
observatory = Observatory(
    mount=create_mount_simulator(),
    cameras=create_camera_simulator(),
    scheduler=create_scheduler_from_config()
)
# Out:
# 2020-06-16 16:43:46.284 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config ["weather","power","night"]
#
# 2020-06-16 16:43:46.289 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:46.297 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=simulator: config_entry=['weather', 'power', 'night']
# 2020-06-16 16:43:46.307 | WARNING  | panoptes.pocs.mount:create_mount_simulator:110 - Current simulators: ['weather', 'power', 'night']
# 2020-06-16 16:43:46.486 | DEBUG    | panoptes.pocs.utils.location:create_location_from_config:27 - Setting up site details
# 2020-06-16 16:43:46.513 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config {"elevation":"3400.0 m","flat_horizon":"-6.0 deg","focus_horizon":"-12.0 deg","gmt_offset":-600,"horizon":"35 deg","latitude":"19.54 deg","longitude":"-155.58 deg","name":"Mauna Loa Observatory","obsctructions":[],"observe_horizon":"-18.0 deg","timezone":"US/Hawaii"}
#
# 2020-06-16 16:43:46.519 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:46.528 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location: config_entry={'elevation': <Quantity 3400. m>, 'flat_horizon': <Quantity -6. deg>, 'focus_horizon': <Quantity -12. deg>, 'gmt_offset': -600, 'horizon': <Quantity 35. deg>, 'latitude': <Quantity 19.54 deg>, 'longitude': <Quantity -155.58 deg>, 'name': 'Mauna Loa Observatory', 'obsctructions': [], 'observe_horizon': <Quantity -18. deg>, 'timezone': 'US/Hawaii'}
# 2020-06-16 16:43:46.540 | DEBUG    | panoptes.pocs.utils.location:create_location_from_config:60 - Location: {'name': 'Mauna Loa Observatory', 'latitude': <Quantity 19.54 deg>, 'longitude': <Quantity -155.58 deg>, 'elevation': <Quantity 3400. m>, 'timezone': 'US/Hawaii', 'pressure': <Quantity 0.68 bar>, 'horizon': <Quantity 35. deg>, 'flat_horizon': <Quantity -6. deg>, 'focus_horizon': <Quantity -12. deg>, 'observe_horizon': <Quantity -18. deg>}
# 2020-06-16 16:43:46.548 | DEBUG    | panoptes.pocs.mount:create_mount_simulator:127 - Loading mount driver: pocs.mount.simulator
# 2020-06-16 16:43:46.560 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:46.565 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:46.571 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:46.589 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:46.596 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:46.607 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:46.614 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:46.630 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config {"driver":"simulator","model":"simulator","serial":{"port":"simulator"}}
#
# 2020-06-16 16:43:46.639 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:46.644 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=mount: config_entry={'driver': 'simulator', 'model': 'simulator', 'serial': {'port': 'simulator'}}
# 2020-06-16 16:43:46.655 | DEBUG    | panoptes.pocs.mount.mount:__init__:46 - Mount config: {'driver': 'simulator', 'model': 'simulator', 'serial': {'port': 'simulator'}}
# 2020-06-16 16:43:46.663 | DEBUG    | panoptes.pocs.mount.mount:__init__:49 - Setting up commands for mount
# 2020-06-16 16:43:46.667 | DEBUG    | panoptes.pocs.mount.mount:__init__:53 - Mount commands set up
# 2020-06-16 16:43:46.672 | INFO     | panoptes.pocs.mount.simulator:__init__:19 - 		Using simulator mount
# 2020-06-16 16:43:46.687 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=loop_delay: config_entry=0.01
# 2020-06-16 16:43:46.693 | DEBUG    | panoptes.pocs.mount.mount:set_park_coordinates:230 - Setting park position
# 2020-06-16 16:43:46.715 | DEBUG    | panoptes.pocs.mount.mount:set_park_coordinates:236 - LST: 0.0514039878630399 hourangle
# 2020-06-16 16:43:46.720 | DEBUG    | panoptes.pocs.mount.mount:set_park_coordinates:237 - HA: -170.0 deg
# 2020-06-16 16:43:46.726 | DEBUG    | panoptes.pocs.mount.mount:set_park_coordinates:240 - RA: 11.384737321196376 hourangle
# 2020-06-16 16:43:46.730 | DEBUG    | panoptes.pocs.mount.mount:set_park_coordinates:241 - Dec: -10.0 deg
# 2020-06-16 16:43:46.741 | DEBUG    | panoptes.pocs.mount.mount:set_park_coordinates:245 - Park Coordinates RA-Dec: <SkyCoord (ICRS): (ra, dec) in deg
#     (170.77105982, -10.)>
# 2020-06-16 16:43:46.751 | DEBUG    | panoptes.pocs.mount.simulator:__init__:26 - Simulator mount created
# 2020-06-16 16:43:46.757 | SUCCESS  | panoptes.pocs.mount:create_mount_simulator:135 - simulator mount created
# 2020-06-16 16:43:46.766 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:212 - SimulatorCamera config: device_config={'model': 'simulator', 'port': '/dev/camera/simulator', 'focuser': {'model': 'simulator', 'focus_port': '/dev/ttyFAKE', 'initial_position': 20000, 'autofocus_range': (40, 80), 'autofocus_step': (10, 20), 'autofocus_seconds': 0.1, 'autofocus_size': 500}, 'filterwheel': {'model': 'simulator', 'filter_names': ['one', 'deux', 'drei', 'quattro'], 'move_time': <Quantity 0.1 s>, 'timeout': <Quantity 0.5 s>}, 'readout_time': 0.5}
# 2020-06-16 16:43:46.779 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:218 - Using camera simulator SimCam00
# 2020-06-16 16:43:46.786 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:221 - Creating camera: simulator
# 2020-06-16 16:43:46.794 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:224 - Camera module: <module 'panoptes.pocs.camera.simulator' from '/var/panoptes/POCS/src/panoptes/pocs/camera/simulator/__init__.py'>
# 2020-06-16 16:43:46.810 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:46.814 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:46.819 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:46.839 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:46.844 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:46.851 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:46.857 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:46.870 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:46.879 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:46.885 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:46.902 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:46.907 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:46.914 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:46.921 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:46.927 | DEBUG    | panoptes.pocs.focuser.focuser:__init__:93 - Focuser created: Simulated Focuser on /dev/ttyFAKE
# 2020-06-16 16:43:46.931 | DEBUG    | panoptes.pocs.focuser.simulator:__init__:17 - Initialising simulator focuser
# 2020-06-16 16:43:47.036 | DEBUG    | panoptes.pocs.focuser.simulator:connect:59 - Connected to focuser SF1996
# 2020-06-16 16:43:47.039 | INFO     | panoptes.pocs.focuser.simulator:__init__:20 - Simulated Focuser (SF1996) on /dev/ttyFAKE initialised
# 2020-06-16 16:43:47.052 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:47.055 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.066 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:47.083 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:47.090 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.097 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:47.102 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:47.108 | DEBUG    | panoptes.pocs.filterwheel.filterwheel:__init__:57 - Filter wheel created: Simulated Filter Wheel (None) on XXXXXX
# 2020-06-16 16:43:47.111 | INFO     | panoptes.pocs.filterwheel.simulator:__init__:54 - Filter wheel Simulated Filter Wheel (SW7525) on XXXXXX initialised
# 2020-06-16 16:43:47.116 | DEBUG    | panoptes.pocs.camera.camera:__init__:139 - Camera created: SimCam00 (XXXXXX) on /dev/camera/simulator with Simulated Focuser & Simulated Filter Wheel
# 2020-06-16 16:43:47.120 | DEBUG    | panoptes.pocs.camera.simulator.dslr:connect:37 - SimCam00 connected
# 2020-06-16 16:43:47.128 | INFO     | panoptes.pocs.camera.simulator.dslr:__init__:25 - SimCam00 (SC5965) on /dev/camera/simulator with Simulated Focuser & Simulated Filter Wheel initialised
# 2020-06-16 16:43:47.137 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:235 - Camera created: SimCam00 SC5965 [Primary]
# 2020-06-16 16:43:47.142 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:218 - Using camera simulator SimCam01
# 2020-06-16 16:43:47.146 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:221 - Creating camera: simulator
# 2020-06-16 16:43:47.151 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:224 - Camera module: <module 'panoptes.pocs.camera.simulator' from '/var/panoptes/POCS/src/panoptes/pocs/camera/simulator/__init__.py'>
# 2020-06-16 16:43:47.169 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:47.174 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.180 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:47.199 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:47.204 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.211 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:47.219 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:47.235 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:47.237 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.242 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:47.257 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:47.261 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.267 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:47.276 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:47.284 | DEBUG    | panoptes.pocs.focuser.focuser:__init__:93 - Focuser created: Simulated Focuser on /dev/ttyFAKE
# 2020-06-16 16:43:47.290 | DEBUG    | panoptes.pocs.focuser.simulator:__init__:17 - Initialising simulator focuser
# 2020-06-16 16:43:47.395 | DEBUG    | panoptes.pocs.focuser.simulator:connect:59 - Connected to focuser SF6575
# 2020-06-16 16:43:47.400 | INFO     | panoptes.pocs.focuser.simulator:__init__:20 - Simulated Focuser (SF6575) on /dev/ttyFAKE initialised
# 2020-06-16 16:43:47.414 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:47.421 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.428 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:47.440 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:47.443 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.448 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:47.452 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:47.456 | DEBUG    | panoptes.pocs.filterwheel.filterwheel:__init__:57 - Filter wheel created: Simulated Filter Wheel (None) on XXXXXX
# 2020-06-16 16:43:47.459 | INFO     | panoptes.pocs.filterwheel.simulator:__init__:54 - Filter wheel Simulated Filter Wheel (SW4051) on XXXXXX initialised
# 2020-06-16 16:43:47.466 | DEBUG    | panoptes.pocs.camera.camera:__init__:139 - Camera created: SimCam01 (XXXXXX) on /dev/camera/simulator with Simulated Focuser & Simulated Filter Wheel
# 2020-06-16 16:43:47.476 | DEBUG    | panoptes.pocs.camera.simulator.dslr:connect:37 - SimCam01 connected
# 2020-06-16 16:43:47.484 | INFO     | panoptes.pocs.camera.simulator.dslr:__init__:25 - SimCam01 (SC9250) on /dev/camera/simulator with Simulated Focuser & Simulated Filter Wheel initialised
# 2020-06-16 16:43:47.489 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:235 - Camera created: SimCam01 SC9250
# 2020-06-16 16:43:47.501 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:239 - Primary camera: SimCam00 [Primary] (SC5965) on /dev/camera/simulator with Simulated Focuser & Simulated Filter Wheel
# 2020-06-16 16:43:47.511 | DEBUG    | panoptes.pocs.camera:create_camera_simulator:240 - 2 cameras created
# 2020-06-16 16:43:47.527 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config {"check_file":true,"fields_file":"simple.yaml","type":"dispatch"}
#
# 2020-06-16 16:43:47.530 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.534 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=scheduler: config_entry={'check_file': True, 'fields_file': 'simple.yaml', 'type': 'dispatch'}
# 2020-06-16 16:43:47.542 | INFO     | panoptes.pocs.scheduler:create_scheduler_from_config:25 - scheduler_config: {'check_file': True, 'fields_file': 'simple.yaml', 'type': 'dispatch'}
# 2020-06-16 16:43:47.549 | DEBUG    | panoptes.pocs.scheduler:create_scheduler_from_config:32 - No Observer provided, creating from config.
# 2020-06-16 16:43:47.554 | DEBUG    | panoptes.pocs.utils.location:create_location_from_config:27 - Setting up site details
# 2020-06-16 16:43:47.578 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config {"elevation":"3400.0 m","flat_horizon":"-6.0 deg","focus_horizon":"-12.0 deg","gmt_offset":-600,"horizon":"35 deg","latitude":"19.54 deg","longitude":"-155.58 deg","name":"Mauna Loa Observatory","obsctructions":[],"observe_horizon":"-18.0 deg","timezone":"US/Hawaii"}
#
# 2020-06-16 16:43:47.588 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.601 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location: config_entry={'elevation': <Quantity 3400. m>, 'flat_horizon': <Quantity -6. deg>, 'focus_horizon': <Quantity -12. deg>, 'gmt_offset': -600, 'horizon': <Quantity 35. deg>, 'latitude': <Quantity 19.54 deg>, 'longitude': <Quantity -155.58 deg>, 'name': 'Mauna Loa Observatory', 'obsctructions': [], 'observe_horizon': <Quantity -18. deg>, 'timezone': 'US/Hawaii'}
# 2020-06-16 16:43:47.624 | DEBUG    | panoptes.pocs.utils.location:create_location_from_config:60 - Location: {'name': 'Mauna Loa Observatory', 'latitude': <Quantity 19.54 deg>, 'longitude': <Quantity -155.58 deg>, 'elevation': <Quantity 3400. m>, 'timezone': 'US/Hawaii', 'pressure': <Quantity 0.68 bar>, 'horizon': <Quantity 35. deg>, 'flat_horizon': <Quantity -6. deg>, 'focus_horizon': <Quantity -12. deg>, 'observe_horizon': <Quantity -18. deg>}
# 2020-06-16 16:43:47.658 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "/var/panoptes/POCS/resources/targets"
#
# 2020-06-16 16:43:47.671 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.677 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.targets: config_entry=/var/panoptes/POCS/resources/targets
# 2020-06-16 16:43:47.683 | DEBUG    | panoptes.pocs.scheduler:create_scheduler_from_config:41 - Creating scheduler: /var/panoptes/POCS/resources/targets/simple.yaml
# 2020-06-16 16:43:47.710 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.obstructions: config_entry=[]
# 2020-06-16 16:43:47.731 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "35 deg"
#
# 2020-06-16 16:43:47.736 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.740 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.horizon: config_entry=35.0 deg
# 2020-06-16 16:43:47.767 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:47.772 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.777 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:47.791 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:47.794 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.799 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:47.803 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:47.815 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:47.819 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.825 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:47.837 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:47.846 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.853 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:47.860 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:47.879 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:47.884 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.890 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:47.910 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:47.921 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.932 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:47.942 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:47.971 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:47.977 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:47.984 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:48.024 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:48.036 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.042 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:48.053 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:48.067 | INFO     | panoptes.pocs.scheduler.scheduler:current_observation:128 - Setting new observation to None
# 2020-06-16 16:43:48.072 | DEBUG    | panoptes.pocs.scheduler.scheduler:read_field_list:255 - Reading fields from file: /var/panoptes/POCS/resources/targets/simple.yaml
# 2020-06-16 16:43:48.274 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Kepler 488'), ('position', '18h51m51.88s +48d20m42.3s'), ('priority', 125)]) to scheduler
# 2020-06-16 16:43:48.300 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:48.304 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.316 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:48.334 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:48.339 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.346 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:48.352 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:48.376 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Kepler 488'
# 2020-06-16 16:43:48.381 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Kepler 488'), ('position', '18h51m51.88s +48d20m42.3s'), ('priority', 125)])
# 2020-06-16 16:43:48.394 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:48.397 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.402 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:48.416 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:48.419 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.424 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:48.430 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:48.446 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:43:48.451 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.456 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:43:48.460 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Kepler 488: 120.0 s exposures in blocks of 10, minimum 60, priority 125
# 2020-06-16 16:43:48.464 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Kepler 488: 120.0 s exposures in blocks of 10, minimum 60, priority 125
# 2020-06-16 16:43:48.477 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Kepler 488'
# 2020-06-16 16:43:48.482 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec1940d0> added
# 2020-06-16 16:43:48.487 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Kepler 1100'), ('position', '19h27m29.10s +44d05m15.00s'), ('priority', 125)]) to scheduler
# 2020-06-16 16:43:48.502 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:48.507 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.513 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:48.535 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:48.541 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.552 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:48.560 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:48.582 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Kepler 1100'
# 2020-06-16 16:43:48.593 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Kepler 1100'), ('position', '19h27m29.10s +44d05m15.00s'), ('priority', 125)])
# 2020-06-16 16:43:48.625 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:48.633 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.641 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:48.664 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:48.680 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.687 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:48.697 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:48.728 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:43:48.738 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.743 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:43:48.752 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Kepler 1100: 120.0 s exposures in blocks of 10, minimum 60, priority 125
# 2020-06-16 16:43:48.764 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Kepler 1100: 120.0 s exposures in blocks of 10, minimum 60, priority 125
# 2020-06-16 16:43:48.774 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Kepler 1100'
# 2020-06-16 16:43:48.781 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec16f970> added
# 2020-06-16 16:43:48.790 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'KIC 8462852'), ('position', '20h06m15.4536s +44d27m24.75s'), ('priority', 200)]) to scheduler
# 2020-06-16 16:43:48.812 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:48.819 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.823 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:48.843 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:48.848 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.854 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:48.859 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:48.868 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='KIC 8462852'
# 2020-06-16 16:43:48.878 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'KIC 8462852'), ('position', '20h06m15.4536s +44d27m24.75s'), ('priority', 200)])
# 2020-06-16 16:43:48.905 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:48.918 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.931 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:48.960 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:48.969 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:48.982 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:48.993 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:49.017 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:43:49.022 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.036 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:43:49.043 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation KIC 8462852: 120.0 s exposures in blocks of 10, minimum 60, priority 200
# 2020-06-16 16:43:49.057 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: KIC 8462852: 120.0 s exposures in blocks of 10, minimum 60, priority 200
# 2020-06-16 16:43:49.070 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='KIC 8462852'
# 2020-06-16 16:43:49.082 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec16fc10> added
# 2020-06-16 16:43:49.088 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'HD 23630'), ('position', '03h47m29.077s +24d06m18.49s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:43:49.110 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:49.117 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.133 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:49.153 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:49.165 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.182 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:49.190 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:49.208 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='HD 23630'
# 2020-06-16 16:43:49.215 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'HD 23630'), ('position', '03h47m29.077s +24d06m18.49s'), ('priority', 100)])
# 2020-06-16 16:43:49.239 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:49.249 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.257 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:49.289 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:49.295 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.305 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:49.313 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:49.333 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:43:49.339 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.349 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:43:49.356 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation HD 23630: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:43:49.365 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: HD 23630: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:43:49.372 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='HD 23630'
# 2020-06-16 16:43:49.381 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec176ee0> added
# 2020-06-16 16:43:49.386 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'HD 189733'), ('position', '20h00m43.713s +22d42m39.07s'), ('priority', 105), ('exptime', <Quantity 100. s>)]) to scheduler
# 2020-06-16 16:43:49.406 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:49.411 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.421 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:49.441 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:49.445 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.449 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:49.453 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:49.461 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='HD 189733'
# 2020-06-16 16:43:49.465 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'HD 189733'), ('position', '20h00m43.713s +22d42m39.07s'), ('priority', 105), ('exptime', <Quantity 100. s>)])
# 2020-06-16 16:43:49.481 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:49.484 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.490 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:49.502 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:49.506 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.510 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:49.514 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:49.526 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:43:49.529 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.535 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:43:49.539 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation HD 189733: 100.0 s exposures in blocks of 10, minimum 60, priority 105
# 2020-06-16 16:43:49.543 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: HD 189733: 100.0 s exposures in blocks of 10, minimum 60, priority 105
# 2020-06-16 16:43:49.549 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='HD 189733'
# 2020-06-16 16:43:49.553 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec16cf10> added
# 2020-06-16 16:43:49.557 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'HD 209458'), ('position', '22h03m10.7721s +18d53m03.543s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:43:49.577 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:49.584 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.592 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:49.615 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:49.622 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.628 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:49.637 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:49.654 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='HD 209458'
# 2020-06-16 16:43:49.660 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'HD 209458'), ('position', '22h03m10.7721s +18d53m03.543s'), ('priority', 100)])
# 2020-06-16 16:43:49.679 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:49.685 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.691 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:49.720 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:49.727 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.732 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:49.739 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:49.771 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:43:49.777 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.782 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:43:49.788 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation HD 209458: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:43:49.793 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: HD 209458: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:43:49.802 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='HD 209458'
# 2020-06-16 16:43:49.816 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec16cd90> added
# 2020-06-16 16:43:49.823 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 140'), ('position', '04h01m32.54s -20d27m03.9s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:43:49.845 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:49.855 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.865 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:49.890 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:49.895 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.903 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:49.908 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:49.918 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 140'
# 2020-06-16 16:43:49.921 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 140'), ('position', '04h01m32.54s -20d27m03.9s'), ('priority', 100)])
# 2020-06-16 16:43:49.937 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:49.940 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.944 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:49.961 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:49.964 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.970 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:49.976 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:49.989 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:43:49.993 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:49.997 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:43:50.001 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Wasp 140: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:43:50.006 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Wasp 140: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:43:50.010 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Wasp 140'
# 2020-06-16 16:43:50.015 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec15e520> added
# 2020-06-16 16:43:50.019 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 104'), ('position', '10h42m24.61s +07d26m06.3s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:43:50.032 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:50.036 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:50.040 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:50.053 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:50.056 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:50.062 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:50.068 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:50.080 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 104'
# 2020-06-16 16:43:50.090 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 104'), ('position', '10h42m24.61s +07d26m06.3s'), ('priority', 100)])
# 2020-06-16 16:43:50.108 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:50.111 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:50.116 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:50.128 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:50.132 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:50.137 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:50.141 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:50.157 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:43:50.160 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:50.165 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:43:50.169 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Wasp 104: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:43:50.173 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Wasp 104: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:43:50.182 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Wasp 104'
# 2020-06-16 16:43:50.185 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87e6587190> added
# 2020-06-16 16:43:50.192 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 44'), ('position', '00h15m36.76s -11d56m17.4s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:43:50.207 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:50.210 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:50.215 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:50.229 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:50.231 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:50.236 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:43:50.240 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:43:50.250 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 44'
# 2020-06-16 16:43:50.254 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 44'), ('position', '00h15m36.76s -11d56m17.4s'), ('priority', 100)])
# 2020-06-16 16:43:50.270 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:43:50.273 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:43:50.278 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:43:50.293 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:43:50.297 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# ...
# 2020-06-16 16:44:00.648 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'M5'), ('position', '15h18m33.2201s +02d04m51.7008s'), ('priority', 50)]) to scheduler
# 2020-06-16 16:44:00.659 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:44:00.662 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:00.665 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:44:00.678 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:44:00.681 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:00.685 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:44:00.690 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:44:00.699 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='M5'
# 2020-06-16 16:44:00.703 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'M5'), ('position', '15h18m33.2201s +02d04m51.7008s'), ('priority', 50)])
# 2020-06-16 16:44:00.717 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:44:00.721 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:00.726 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:44:00.738 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:44:00.741 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:00.745 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:44:00.751 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:44:00.765 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:44:00.769 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:00.787 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:44:00.793 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation M5: 120.0 s exposures in blocks of 10, minimum 60, priority 50
# 2020-06-16 16:44:00.799 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: M5: 120.0 s exposures in blocks of 10, minimum 60, priority 50
# 2020-06-16 16:44:00.804 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='M5'
# 2020-06-16 16:44:00.811 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='M5'
# 2020-06-16 16:44:00.820 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec101430> added
# 2020-06-16 16:44:00.832 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'CoRoT-18'), ('position', '06h32m41.38s -00d01m53.s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:44:00.858 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:44:00.864 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:00.869 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:44:00.888 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:44:00.892 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:00.899 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:44:00.905 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:44:00.916 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='CoRoT-18'
# 2020-06-16 16:44:00.919 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'CoRoT-18'), ('position', '06h32m41.38s -00d01m53.s'), ('priority', 100)])
# 2020-06-16 16:44:00.930 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:44:00.933 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:00.937 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:44:00.947 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:44:00.950 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:00.954 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:44:00.958 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:44:00.968 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:44:00.971 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:00.974 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:44:00.978 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation CoRoT-18: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:44:00.981 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: CoRoT-18: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:44:00.984 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='CoRoT-18'
# 2020-06-16 16:44:00.988 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='CoRoT-18'
# 2020-06-16 16:44:00.991 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec179c40> added
# 2020-06-16 16:44:00.995 | DEBUG    | panoptes.pocs.scheduler:create_scheduler_from_config:67 - Scheduler created
# 2020-06-16 16:44:01.004 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:44:01.008 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:01.012 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:44:01.021 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:44:01.024 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:01.029 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:44:01.033 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:44:01.037 | INFO     | panoptes.pocs.observatory:__init__:33 - Initializing observatory
# 2020-06-16 16:44:01.041 | INFO     | panoptes.pocs.observatory:__init__:36 - Setting up location
# 2020-06-16 16:44:01.044 | DEBUG    | panoptes.pocs.utils.location:create_location_from_config:27 - Setting up site details
# 2020-06-16 16:44:01.054 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config {"elevation":"3400.0 m","flat_horizon":"-6.0 deg","focus_horizon":"-12.0 deg","gmt_offset":-600,"horizon":"35 deg","latitude":"19.54 deg","longitude":"-155.58 deg","name":"Mauna Loa Observatory","obsctructions":[],"observe_horizon":"-18.0 deg","timezone":"US/Hawaii"}
#
# 2020-06-16 16:44:01.057 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:01.064 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location: config_entry={'elevation': <Quantity 3400. m>, 'flat_horizon': <Quantity -6. deg>, 'focus_horizon': <Quantity -12. deg>, 'gmt_offset': -600, 'horizon': <Quantity 35. deg>, 'latitude': <Quantity 19.54 deg>, 'longitude': <Quantity -155.58 deg>, 'name': 'Mauna Loa Observatory', 'obsctructions': [], 'observe_horizon': <Quantity -18. deg>, 'timezone': 'US/Hawaii'}
# 2020-06-16 16:44:01.073 | DEBUG    | panoptes.pocs.utils.location:create_location_from_config:60 - Location: {'name': 'Mauna Loa Observatory', 'latitude': <Quantity 19.54 deg>, 'longitude': <Quantity -155.58 deg>, 'elevation': <Quantity 3400. m>, 'timezone': 'US/Hawaii', 'pressure': <Quantity 0.68 bar>, 'horizon': <Quantity 35. deg>, 'flat_horizon': <Quantity -6. deg>, 'focus_horizon': <Quantity -12. deg>, 'observe_horizon': <Quantity -18. deg>}
# 2020-06-16 16:44:02.180 | SUCCESS  | panoptes.pocs.observatory:_set_hardware:245 - Adding new_hardware=<panoptes.pocs.mount.simulator.Mount object at 0x7f87e5a37cd0>
# 2020-06-16 16:44:02.186 | INFO     | panoptes.pocs.observatory:__init__:56 - Adding the cameras to the observatory: OrderedDict([('SimCam00', <panoptes.pocs.camera.simulator.dslr.Camera object at 0x7f87e5a10f10>), ('SimCam01', <panoptes.pocs.camera.simulator.dslr.Camera object at 0x7f87ec195250>)])
# 2020-06-16 16:44:02.191 | DEBUG    | panoptes.pocs.observatory:add_camera:194 - Adding SimCam00: SimCam00 [Primary] (SC5965) on /dev/camera/simulator with Simulated Focuser & Simulated Filter Wheel
# 2020-06-16 16:44:02.195 | DEBUG    | panoptes.pocs.observatory:add_camera:194 - Adding SimCam01: SimCam01 (SC9250) on /dev/camera/simulator with Simulated Focuser & Simulated Filter Wheel
# 2020-06-16 16:44:02.201 | SUCCESS  | panoptes.pocs.observatory:_set_hardware:245 - Adding new_hardware=<panoptes.pocs.scheduler.dispatch.Scheduler object at 0x7f87ec15e3d0>
# 2020-06-16 16:44:02.216 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:44:02.222 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:02.228 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:44:02.236 | SUCCESS  | panoptes.pocs.observatory:__init__:69 - Observatory initialized
# 2020-06-16 16:44:10.224 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:44:10.228 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:10.231 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:44:10.234 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:44:10.238 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:44:10.241 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:44:10.245 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:44:11.554 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:44:11.558 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:11.563 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:44:11.568 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:44:11.572 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:44:32.484 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:44:32.487 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:32.492 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:44:32.497 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:44:32.500 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:44:32.505 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:44:32.511 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:44:33.304 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:44:33.307 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:44:33.310 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:44:33.314 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:44:33.318 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:45:11.654 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:45:11.666 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:11.680 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:45:11.693 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:45:11.705 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:45:11.731 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:45:11.754 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:45:13.366 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:45:13.384 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:13.394 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:45:13.407 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:45:13.420 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:45:33.387 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:45:33.395 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:33.407 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:45:33.413 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:45:33.421 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:45:33.428 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:45:33.439 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:45:34.980 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:45:34.986 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:34.992 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:45:34.998 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:45:35.005 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds

# %% [markdown]
# ### Create an instance of POCS that acts as a simulator

# %%
simulators = ['weather', 'power', 'night']  # Could be a list of: 'weather', 'camera', 'mount'

pocs = POCS(observatory=observatory, simulators=simulators)
# Out:
# 2020-06-16 16:45:47.140 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:45:47.147 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:47.158 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:45:47.174 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:45:47.179 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:47.189 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:45:47.194 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:45:47.202 | WARNING  | panoptes.pocs.core:__init__:54 - Using simulators=['weather', 'power', 'night']
# 2020-06-16 16:45:47.370 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "Generic PANOPTES Unit"
#
# 2020-06-16 16:45:47.375 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:47.383 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=name: config_entry=Generic PANOPTES Unit
# 2020-06-16 16:45:47.407 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "Mauna Loa Observatory"
#
# 2020-06-16 16:45:47.411 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:47.428 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.name: config_entry=Mauna Loa Observatory
# 2020-06-16 16:45:47.436 | INFO     | panoptes.pocs.core:__init__:61 - Initializing PANOPTES unit - Generic PANOPTES Unit - Mauna Loa Observatory
# 2020-06-16 16:45:47.471 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "simple_state_table"
#
# 2020-06-16 16:45:47.476 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:47.494 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=state_machine: config_entry=simple_state_table
# 2020-06-16 16:45:47.499 | INFO     | panoptes.pocs.core:__init__:66 - Making a POCS state machine from simple_state_table
# 2020-06-16 16:45:47.508 | INFO     | panoptes.pocs.state.machine:__init__:23 - Loading state table: simple_state_table
# 2020-06-16 16:45:47.703 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: parking
# 2020-06-16 16:45:47.718 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.parking' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/parking.py'>
# 2020-06-16 16:45:47.727 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='parking' with state_info=ordereddict([('tags', 'always_safe')])
# 2020-06-16 16:45:47.733 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: parked
# 2020-06-16 16:45:47.738 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.parked' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/parked.py'>
# 2020-06-16 16:45:47.749 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='parked' with state_info=ordereddict([('tags', 'always_safe')])
# 2020-06-16 16:45:47.758 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: sleeping
# 2020-06-16 16:45:47.772 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.sleeping' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/sleeping.py'>
# 2020-06-16 16:45:47.783 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='sleeping' with state_info=ordereddict([('tags', 'always_safe')])
# 2020-06-16 16:45:47.787 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: housekeeping
# 2020-06-16 16:45:47.795 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.housekeeping' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/housekeeping.py'>
# 2020-06-16 16:45:47.804 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='housekeeping' with state_info=ordereddict([('tags', 'always_safe')])
# 2020-06-16 16:45:47.808 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: ready
# 2020-06-16 16:45:47.820 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.ready' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/ready.py'>
# 2020-06-16 16:45:47.829 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='ready' with state_info=ordereddict([('tags', 'always_safe')])
# 2020-06-16 16:45:47.833 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: scheduling
# 2020-06-16 16:45:47.843 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.scheduling' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/scheduling.py'>
# 2020-06-16 16:45:47.850 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='scheduling' with state_info=ordereddict([('tags', 'always_safe')])
# 2020-06-16 16:45:47.861 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: slewing
# 2020-06-16 16:45:47.871 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.slewing' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/slewing.py'>
# 2020-06-16 16:45:47.879 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='slewing' with state_info={}
# 2020-06-16 16:45:47.884 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: pointing
# 2020-06-16 16:45:47.896 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.pointing' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/pointing.py'>
# 2020-06-16 16:45:47.901 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='pointing' with state_info={}
# 2020-06-16 16:45:47.912 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: tracking
# 2020-06-16 16:45:47.922 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.tracking' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/tracking.py'>
# 2020-06-16 16:45:47.930 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='tracking' with state_info={}
# 2020-06-16 16:45:47.935 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: observing
# 2020-06-16 16:45:47.940 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.observing' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/observing.py'>
# 2020-06-16 16:45:47.946 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='observing' with state_info={}
# 2020-06-16 16:45:47.951 | DEBUG    | panoptes.pocs.state.machine:_load_state:338 - Loading state: analyzing
# 2020-06-16 16:45:47.956 | DEBUG    | panoptes.pocs.state.machine:_load_state:347 - Checking <module 'panoptes.pocs.state.states.default.analyzing' from '/var/panoptes/POCS/src/panoptes/pocs/state/states/default/analyzing.py'>
# 2020-06-16 16:45:47.967 | DEBUG    | panoptes.pocs.state.machine:_load_state:361 - Creating state='analyzing' with state_info={}
# 2020-06-16 16:45:47.976 | DEBUG    | panoptes.pocs.state.machine:__init__:48 - Horizon limits: {'scheduling': 'observe'}
# 2020-06-16 16:45:47.991 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:45:47.995 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:48.002 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:45:48.021 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:45:48.029 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:48.034 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:45:48.042 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:45:48.052 | DEBUG    | panoptes.pocs.state.machine:__init__:66 - State machine created
# 2020-06-16 16:45:48.330 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.RETRY_ATTEMPTS: config_entry=3
# 2020-06-16 16:45:48.604 | SUCCESS  | panoptes.pocs.core:say:226 - Unit says: Hi there!
# 2020-06-16 16:45:48.624 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:45:48.634 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:48.649 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:45:50.085 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:45:50.099 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:50.111 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:45:50.124 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:45:50.131 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds

# %% [markdown]
# The `pocs` instance needs to be initialized, which will set up the cameras, mount, scheduler, etc.

# %%
pocs.initialize()
# Out:
# 2020-06-16 03:51:30.094 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config false
#
# 2020-06-16 03:51:30.097 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 03:51:30.098 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.INITIALIZED: config_entry=False
# 2020-06-16 03:51:30.100 | INFO     | panoptes.pocs.core:initialize:201 - ********************************************************************************
# 2020-06-16 03:51:30.101 | SUCCESS  | panoptes.pocs.core:say:226 - Unit says: Initializing the system! Woohoo!
# 2020-06-16 03:51:30.102 | DEBUG    | panoptes.pocs.core:initialize:205 - Initializing observatory
# 2020-06-16 03:51:30.104 | DEBUG    | panoptes.pocs.observatory:initialize:260 - Initializing mount
# 2020-06-16 03:51:30.105 | DEBUG    | panoptes.pocs.mount.simulator:initialize:51 - Initializing simulator mount
# 2020-06-16 03:51:30.106 | DEBUG    | panoptes.pocs.mount.simulator:connect:65 - Connecting to mount simulator
# 2020-06-16 03:51:30.108 | DEBUG    | panoptes.pocs.mount.simulator:_setup_location_for_mount:206 - Setting up mount for location
# 2020-06-16 03:51:30.183 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 03:51:30.185 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 03:51:30.188 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.INITIALIZED: config_entry=True
# True

# %% [markdown]
# During automated operations a script would simply call `pocs.run()` and the state machine would begin. However, the `run()` method is a blocking call so you can't interact with the system any more. Here we manually inspect some items.

# %%
# Check if we have a current observation:
print(pocs.observatory.current_observation)
# Out:
# None

# %%
pocs.observatory.scheduler.clear_available_observations()
# Out:
# 2020-06-16 03:51:36.593 | INFO     | panoptes.pocs.scheduler.scheduler:current_observation:128 - Setting new observation to None

# %%
pocs.observatory.scheduler.add_observation({
    'name': 'HIP 36850',
    'position': '113.65 deg +31.887 deg',
    'priority': '100',
    'exptime': 2,
    'min_nexp': 2,
    'exp_set_size': 2,
})
# Out:
# 2020-06-16 03:51:40.015 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config={'name': 'HIP 36850', 'position': '113.65 deg +31.887 deg', 'priority': '100', 'exptime': <Quantity 2. s>, 'min_nexp': 2, 'exp_set_size': 2} to scheduler
# 2020-06-16 03:51:40.022 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 03:51:40.023 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 03:51:40.025 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 03:51:40.030 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 03:51:40.032 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 03:51:40.034 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 03:51:40.034 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 03:51:40.037 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='HIP 36850'
# 2020-06-16 03:51:40.040 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for {'name': 'HIP 36850', 'position': '113.65 deg +31.887 deg', 'priority': '100', 'exptime': <Quantity 2. s>, 'min_nexp': 2, 'exp_set_size': 2}
# 2020-06-16 03:51:40.047 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 03:51:40.050 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 03:51:40.053 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 03:51:40.059 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 03:51:40.060 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 03:51:40.063 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 03:51:40.065 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 03:51:40.074 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 03:51:40.078 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 03:51:40.081 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 03:51:40.082 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation HIP 36850: 2.0 s exposures in blocks of 2, minimum 2, priority 100
# 2020-06-16 03:51:40.084 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: HIP 36850: 2.0 s exposures in blocks of 2, minimum 2, priority 100
# 2020-06-16 03:51:40.086 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='HIP 36850'
# 2020-06-16 03:51:40.088 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f38b004a6d0> added

# %%
os.environ['POCSTIME'] = '2020-01-01 09:00:00'

# %%
print(pocs.observatory.current_observation)
# Out:
# None

# %%
# Set a new high priority target. (NOTE this is a totally fake thing)
target = {
    'name': 'Super Grav Wave Event',
    'position': '22h57m47.0s +38d40m30.0s',
    'priority': 999,    
}

pocs.observatory.scheduler.add_observation(target)
# Out:
# 2020-06-16 16:45:56.211 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config={'name': 'Super Grav Wave Event', 'position': '22h57m47.0s +38d40m30.0s', 'priority': 999} to scheduler
# 2020-06-16 16:45:56.229 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:45:56.234 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:56.240 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:45:56.256 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:45:56.264 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:56.270 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:45:56.278 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:45:56.291 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Super Grav Wave Event'
# 2020-06-16 16:45:56.298 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for {'name': 'Super Grav Wave Event', 'position': '22h57m47.0s +38d40m30.0s', 'priority': 999}
# 2020-06-16 16:45:56.328 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:45:56.337 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:56.354 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:45:56.393 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:45:56.405 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:56.415 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:45:56.426 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:45:56.448 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:45:56.460 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:45:56.476 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:45:56.482 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Super Grav Wave Event: 120.0 s exposures in blocks of 10, minimum 60, priority 999
# 2020-06-16 16:45:56.489 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Super Grav Wave Event: 120.0 s exposures in blocks of 10, minimum 60, priority 999
# 2020-06-16 16:45:56.495 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Super Grav Wave Event'
# 2020-06-16 16:45:56.499 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87e6582a60> added

# %%
# Get a new observation, which should be our new event
new_obs = pocs.observatory.get_observation()
# Out:
# 2020-06-16 16:46:10.121 | DEBUG    | panoptes.pocs.observatory:get_observation:340 - Getting observation for observatory
# 2020-06-16 16:46:10.151 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:46:10.157 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.161 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=scheduler.check_file: config_entry=True
# 2020-06-16 16:46:10.166 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:27 - Rereading fields file
# 2020-06-16 16:46:10.174 | DEBUG    | panoptes.pocs.scheduler.scheduler:read_field_list:255 - Reading fields from file: /var/panoptes/POCS/resources/targets/simple.yaml
# 2020-06-16 16:46:10.411 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Kepler 488'), ('position', '18h51m51.88s +48d20m42.3s'), ('priority', 125)]) to scheduler
# 2020-06-16 16:46:10.436 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:10.442 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.457 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:10.478 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:10.483 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.487 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:10.493 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:10.506 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Kepler 488'
# 2020-06-16 16:46:10.513 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Kepler 488'), ('position', '18h51m51.88s +48d20m42.3s'), ('priority', 125)])
# 2020-06-16 16:46:10.526 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:10.530 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.533 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:10.543 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:10.546 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.550 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:10.553 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:10.571 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:10.579 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.588 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:10.594 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Kepler 488: 120.0 s exposures in blocks of 10, minimum 60, priority 125
# 2020-06-16 16:46:10.607 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Kepler 488: 120.0 s exposures in blocks of 10, minimum 60, priority 125
# 2020-06-16 16:46:10.616 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Kepler 488'
# 2020-06-16 16:46:10.622 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='Kepler 488'
# 2020-06-16 16:46:10.634 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87e5a10280> added
# 2020-06-16 16:46:10.639 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Kepler 1100'), ('position', '19h27m29.10s +44d05m15.00s'), ('priority', 125)]) to scheduler
# 2020-06-16 16:46:10.656 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:10.665 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.676 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:10.705 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:10.712 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.717 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:10.722 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:10.735 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Kepler 1100'
# 2020-06-16 16:46:10.743 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Kepler 1100'), ('position', '19h27m29.10s +44d05m15.00s'), ('priority', 125)])
# 2020-06-16 16:46:10.764 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:10.770 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.775 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:10.798 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:10.805 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.810 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:10.815 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:10.839 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:10.851 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.856 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:10.860 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Kepler 1100: 120.0 s exposures in blocks of 10, minimum 60, priority 125
# 2020-06-16 16:46:10.865 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Kepler 1100: 120.0 s exposures in blocks of 10, minimum 60, priority 125
# 2020-06-16 16:46:10.870 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Kepler 1100'
# 2020-06-16 16:46:10.875 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='Kepler 1100'
# 2020-06-16 16:46:10.883 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec15ef40> added
# 2020-06-16 16:46:10.891 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'KIC 8462852'), ('position', '20h06m15.4536s +44d27m24.75s'), ('priority', 200)]) to scheduler
# 2020-06-16 16:46:10.907 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:10.912 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.917 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:10.930 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:10.935 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.939 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:10.948 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:10.960 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='KIC 8462852'
# 2020-06-16 16:46:10.967 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'KIC 8462852'), ('position', '20h06m15.4536s +44d27m24.75s'), ('priority', 200)])
# 2020-06-16 16:46:10.983 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:10.988 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:10.993 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:11.006 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:11.011 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.018 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:11.025 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:11.042 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:11.047 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.052 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:11.056 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation KIC 8462852: 120.0 s exposures in blocks of 10, minimum 60, priority 200
# 2020-06-16 16:46:11.062 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: KIC 8462852: 120.0 s exposures in blocks of 10, minimum 60, priority 200
# 2020-06-16 16:46:11.067 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='KIC 8462852'
# 2020-06-16 16:46:11.072 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='KIC 8462852'
# 2020-06-16 16:46:11.077 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87e65212b0> added
# 2020-06-16 16:46:11.082 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'HD 23630'), ('position', '03h47m29.077s +24d06m18.49s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:11.095 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:11.101 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.109 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:11.127 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:11.132 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.139 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:11.144 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:11.159 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='HD 23630'
# 2020-06-16 16:46:11.164 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'HD 23630'), ('position', '03h47m29.077s +24d06m18.49s'), ('priority', 100)])
# 2020-06-16 16:46:11.190 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:11.195 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.203 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:11.229 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:11.234 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.240 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:11.245 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:11.263 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:11.268 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.278 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:11.283 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation HD 23630: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:11.288 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: HD 23630: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:11.298 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='HD 23630'
# 2020-06-16 16:46:11.302 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='HD 23630'
# 2020-06-16 16:46:11.309 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87e5a29460> added
# 2020-06-16 16:46:11.315 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'HD 189733'), ('position', '20h00m43.713s +22d42m39.07s'), ('priority', 105), ('exptime', <Quantity 100. s>)]) to scheduler
# 2020-06-16 16:46:11.336 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:11.345 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.359 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:11.375 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:11.379 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.391 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:11.396 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:11.407 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='HD 189733'
# 2020-06-16 16:46:11.416 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'HD 189733'), ('position', '20h00m43.713s +22d42m39.07s'), ('priority', 105), ('exptime', <Quantity 100. s>)])
# 2020-06-16 16:46:11.443 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:11.456 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.461 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:11.476 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:11.480 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.484 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:11.488 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:11.503 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:11.517 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.522 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:11.527 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation HD 189733: 100.0 s exposures in blocks of 10, minimum 60, priority 105
# 2020-06-16 16:46:11.532 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: HD 189733: 100.0 s exposures in blocks of 10, minimum 60, priority 105
# 2020-06-16 16:46:11.538 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='HD 189733'
# 2020-06-16 16:46:11.542 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='HD 189733'
# 2020-06-16 16:46:11.547 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec195d60> added
# 2020-06-16 16:46:11.553 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'HD 209458'), ('position', '22h03m10.7721s +18d53m03.543s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:11.573 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:11.578 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.583 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:11.594 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:11.597 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.602 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:11.606 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:11.616 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='HD 209458'
# 2020-06-16 16:46:11.620 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'HD 209458'), ('position', '22h03m10.7721s +18d53m03.543s'), ('priority', 100)])
# 2020-06-16 16:46:11.635 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:11.637 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.643 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:11.655 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:11.659 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.679 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:11.687 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:11.714 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:11.718 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.730 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:11.736 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation HD 209458: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:11.741 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: HD 209458: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:11.746 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='HD 209458'
# 2020-06-16 16:46:11.751 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='HD 209458'
# 2020-06-16 16:46:11.756 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec1794f0> added
# 2020-06-16 16:46:11.760 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 140'), ('position', '04h01m32.54s -20d27m03.9s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:11.779 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:11.783 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.789 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:11.812 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:11.817 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.824 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:11.833 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:11.848 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 140'
# 2020-06-16 16:46:11.856 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 140'), ('position', '04h01m32.54s -20d27m03.9s'), ('priority', 100)])
# 2020-06-16 16:46:11.875 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:11.879 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.883 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:11.911 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:11.916 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.922 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:11.932 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:11.951 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:11.955 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:11.962 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:11.966 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Wasp 140: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:11.970 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Wasp 140: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:11.973 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Wasp 140'
# 2020-06-16 16:46:11.977 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='Wasp 140'
# 2020-06-16 16:46:11.980 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec179cd0> added
# 2020-06-16 16:46:11.984 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 104'), ('position', '10h42m24.61s +07d26m06.3s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:11.994 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:11.997 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.000 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:12.012 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:12.015 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.021 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:12.025 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:12.036 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 104'
# 2020-06-16 16:46:12.040 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 104'), ('position', '10h42m24.61s +07d26m06.3s'), ('priority', 100)])
# 2020-06-16 16:46:12.052 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:12.055 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.063 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:12.074 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:12.079 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.084 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:12.089 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:12.112 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:12.116 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.122 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:12.131 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Wasp 104: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:12.138 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Wasp 104: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:12.143 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Wasp 104'
# 2020-06-16 16:46:12.148 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='Wasp 104'
# 2020-06-16 16:46:12.153 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87e651eac0> added
# 2020-06-16 16:46:12.156 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 44'), ('position', '00h15m36.76s -11d56m17.4s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:12.172 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:12.176 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.180 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:12.192 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:12.195 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.200 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:12.205 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:12.217 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 44'
# 2020-06-16 16:46:12.220 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 44'), ('position', '00h15m36.76s -11d56m17.4s'), ('priority', 100)])
# 2020-06-16 16:46:12.239 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:12.244 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.249 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:12.268 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:12.279 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.282 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:12.290 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:12.303 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:12.307 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.312 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:12.317 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Wasp 44: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:12.321 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Wasp 44: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:12.327 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Wasp 44'
# 2020-06-16 16:46:12.330 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='Wasp 44'
# 2020-06-16 16:46:12.336 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec1a0340> added
# 2020-06-16 16:46:12.340 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 2'), ('position', '20h30m54.0s +06d25m46.0s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:12.370 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:12.380 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.385 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:12.402 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:12.405 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.414 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:12.418 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:12.425 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 2'
# 2020-06-16 16:46:12.428 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 2'), ('position', '20h30m54.0s +06d25m46.0s'), ('priority', 100)])
# 2020-06-16 16:46:12.440 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:12.443 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.449 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:12.459 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:12.462 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.470 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:12.474 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:12.487 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:12.501 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.505 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:12.526 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Wasp 2: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:12.531 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Wasp 2: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:12.539 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Wasp 2'
# 2020-06-16 16:46:12.546 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='Wasp 2'
# 2020-06-16 16:46:12.552 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec1a00d0> added
# 2020-06-16 16:46:12.557 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 24'), ('position', '15h08m51.739s +02d20m35.95s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:12.568 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:12.571 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.575 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:12.591 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:12.596 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.603 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:12.609 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:12.621 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 24'
# 2020-06-16 16:46:12.627 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 24'), ('position', '15h08m51.739s +02d20m35.95s'), ('priority', 100)])
# 2020-06-16 16:46:12.642 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:12.647 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.652 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:12.665 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:12.670 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.674 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:12.679 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:12.698 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:12.712 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.719 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:12.728 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Wasp 24: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:12.732 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Wasp 24: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:12.739 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Wasp 24'
# 2020-06-16 16:46:12.749 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='Wasp 24'
# 2020-06-16 16:46:12.757 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec16c670> added
# 2020-06-16 16:46:12.764 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 77'), ('position', '02h28m37.22s -07d03m38.45s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:12.781 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:12.791 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.796 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:12.823 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:12.830 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.836 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:12.848 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:12.867 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 77'
# 2020-06-16 16:46:12.876 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 77'), ('position', '02h28m37.22s -07d03m38.45s'), ('priority', 100)])
# 2020-06-16 16:46:12.897 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:12.901 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.907 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:12.926 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:12.930 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.937 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:12.941 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:12.958 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:12.965 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:12.972 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:12.977 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Wasp 77: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:12.987 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Wasp 77: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:12.996 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Wasp 77'
# 2020-06-16 16:46:13.001 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='Wasp 77'
# 2020-06-16 16:46:13.009 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec195280> added
# 2020-06-16 16:46:13.014 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 33'), ('position', '02h26m51.0582s +37d33m01.733s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:13.034 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:13.040 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.046 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:13.068 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:13.072 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.077 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:13.081 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:13.092 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 33'
# 2020-06-16 16:46:13.096 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 33'), ('position', '02h26m51.0582s +37d33m01.733s'), ('priority', 100)])
# 2020-06-16 16:46:13.109 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:13.112 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.116 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:13.128 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:13.131 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.135 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:13.138 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:13.149 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:13.152 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.157 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:13.161 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Wasp 33: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:13.165 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Wasp 33: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:13.175 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Wasp 33'
# 2020-06-16 16:46:13.178 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='Wasp 33'
# 2020-06-16 16:46:13.181 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec16f580> added
# 2020-06-16 16:46:13.185 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 43'), ('position', '10h19m38.008s -09d48m22.59s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:13.200 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:13.203 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.207 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:13.217 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:13.222 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.224 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:13.228 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:13.237 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 43'
# 2020-06-16 16:46:13.240 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:230 - Creating observation for ordereddict([('name', 'Wasp 43'), ('position', '10h19m38.008s -09d48m22.59s'), ('priority', 100)])
# 2020-06-16 16:46:13.252 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:13.254 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.258 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:13.268 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:13.270 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.275 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:13.280 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:13.294 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "images"
#
# 2020-06-16 16:46:13.297 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.301 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=directories.images: config_entry=images
# 2020-06-16 16:46:13.305 | DEBUG    | panoptes.pocs.scheduler.observation:reset:217 - Resetting observation Wasp 43: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:13.309 | DEBUG    | panoptes.pocs.scheduler.observation:__init__:82 - Observation created: Wasp 43: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:13.312 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:232 - Observation created for field.name='Wasp 43'
# 2020-06-16 16:46:13.315 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:237 - Overriding existing entry for field.name='Wasp 43'
# 2020-06-16 16:46:13.318 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:239 - obs=<panoptes.pocs.scheduler.observation.Observation object at 0x7f87ec1aae80> added
# 2020-06-16 16:46:13.322 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:225 - Adding field_config=ordereddict([('name', 'Wasp 36'), ('position', '08h46m19.30s -08d01m36.7s'), ('priority', 100)]) to scheduler
# 2020-06-16 16:46:13.333 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "file"
#
# 2020-06-16 16:46:13.336 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.340 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.type: config_entry=file
# 2020-06-16 16:46:13.361 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "panoptes"
#
# 2020-06-16 16:46:13.366 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:13.387 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=db.name: config_entry=panoptes
# 2020-06-16 16:46:13.393 | INFO     | panoptes.utils.database.base:__init__:55 - Creating PanDB panoptes
# 2020-06-16 16:46:13.408 | DEBUG    | panoptes.pocs.scheduler.scheduler:add_observation:227 - Created field.name='Wasp 36'
# ...
# 2020-06-16 16:46:25.401 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:58 - 		Total score: 1.395
# 2020-06-16 16:46:25.406 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	CoRoT-18	Current score: 1.000
# 2020-06-16 16:46:25.426 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 0.587	Veto: False
# 2020-06-16 16:46:25.429 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:58 - 		Total score: 1.587
# 2020-06-16 16:46:25.434 | INFO     | panoptes.pocs.scheduler.dispatch:get_observation:39 - Checking Constraint: Duration above 35.0 deg
# 2020-06-16 16:46:25.440 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	HD 23630	Current score: 1.395
# 2020-06-16 16:46:25.510 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:25.515 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:25.519 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:26.401 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 1.839	Veto: False
# 2020-06-16 16:46:26.406 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:58 - 		Total score: 3.234
# 2020-06-16 16:46:26.411 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	Wasp 140	Current score: 1.370
# 2020-06-16 16:46:26.498 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:26.503 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:26.517 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:27.365 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 0.967	Veto: True
# 2020-06-16 16:46:27.369 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:53 - 		Vetoed by Duration above 35.0 deg
# 2020-06-16 16:46:27.374 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	Wasp 33	Current score: 1.346
# 2020-06-16 16:46:27.417 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:27.420 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:27.424 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:28.331 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 0.873	Veto: True
# 2020-06-16 16:46:28.338 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:53 - 		Vetoed by Duration above 35.0 deg
# 2020-06-16 16:46:28.345 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	Wasp 11	Current score: 1.366
# 2020-06-16 16:46:28.400 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:28.404 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:28.411 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:29.493 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 1.400	Veto: True
# 2020-06-16 16:46:29.496 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:53 - 		Vetoed by Duration above 35.0 deg
# 2020-06-16 16:46:29.501 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	Wasp 35	Current score: 1.461
# 2020-06-16 16:46:29.540 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:29.543 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:29.547 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:30.503 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 2.294	Veto: False
# 2020-06-16 16:46:30.507 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:58 - 		Total score: 3.755
# 2020-06-16 16:46:30.514 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	HAT-P-20	Current score: 1.670
# 2020-06-16 16:46:30.557 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:30.559 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:30.565 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:31.235 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 4.598	Veto: False
# 2020-06-16 16:46:31.238 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:58 - 		Total score: 6.268
# 2020-06-16 16:46:31.242 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	EPIC-211089792	Current score: 1.423
# 2020-06-16 16:46:31.288 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:31.290 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:31.293 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:31.919 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 2.132	Veto: False
# 2020-06-16 16:46:31.922 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:58 - 		Total score: 3.556
# 2020-06-16 16:46:31.926 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	HAT-P-30	Current score: 1.734
# 2020-06-16 16:46:31.968 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:31.972 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:31.977 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:32.654 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 4.965	Veto: False
# 2020-06-16 16:46:32.657 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:58 - 		Total score: 6.699
# 2020-06-16 16:46:32.661 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	M42	Current score: 1.504
# 2020-06-16 16:46:32.701 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:32.706 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:32.711 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:33.421 | DEBUG    | panoptes.pocs.scheduler.constraint:get_score:103 - 		Observation minimum can't be met before meridian flip
# 2020-06-16 16:46:33.557 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 2.705	Veto: True
# 2020-06-16 16:46:33.561 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:53 - 		Vetoed by Duration above 35.0 deg
# 2020-06-16 16:46:33.564 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	M44	Current score: 1.766
# 2020-06-16 16:46:33.606 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:33.609 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:33.613 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:34.332 | DEBUG    | panoptes.pocs.scheduler.constraint:get_score:115 - 		Target sets past end_of_night, using end_of_night
# 2020-06-16 16:46:34.337 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 5.000	Veto: False
# 2020-06-16 16:46:34.341 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:58 - 		Total score: 6.766
# 2020-06-16 16:46:34.345 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	M45	Current score: 1.395
# 2020-06-16 16:46:34.397 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:34.399 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:34.403 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:35.159 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:46:35.174 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:35.172 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 1.838	Veto: False
# 2020-06-16 16:46:35.179 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:46:35.188 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:58 - 		Total score: 3.233
# 2020-06-16 16:46:35.194 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:46:35.203 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:43 - 	CoRoT-18	Current score: 1.587
# 2020-06-16 16:46:35.207 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:46:35.265 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:46:35.276 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:46:35.318 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config "-18.0 deg"
#
# 2020-06-16 16:46:35.329 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:35.372 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=location.observe_horizon: config_entry=-18.0 deg
# 2020-06-16 16:46:36.670 | DEBUG    | panoptes.pocs.scheduler.constraint:get_score:103 - 		Observation minimum can't be met before meridian flip
# 2020-06-16 16:46:36.686 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:46:36.691 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:36.695 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:46:36.699 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:46:36.702 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:46:36.807 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:50 - 		Constraint Score: 3.556	Veto: True
# 2020-06-16 16:46:36.809 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:53 - 		Vetoed by Duration above 35.0 deg
# 2020-06-16 16:46:36.814 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:60 - Multiplying final scores by priority
# 2020-06-16 16:46:36.819 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:64 - HD 23630:  100.00 *   3.23 =  323.43
# 2020-06-16 16:46:36.824 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:64 - Wasp 35:  100.00 *   3.76 =  375.51
# 2020-06-16 16:46:36.827 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:64 - HAT-P-20:  100.00 *   6.27 =  626.76
# 2020-06-16 16:46:36.832 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:64 - EPIC-211089792:  100.00 *   3.56 =  355.56
# 2020-06-16 16:46:36.842 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:64 - HAT-P-30:  100.00 *   6.70 =  669.88
# 2020-06-16 16:46:36.847 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:64 - M44:   50.00 *   6.77 =  338.29
# 2020-06-16 16:46:36.851 | DEBUG    | panoptes.pocs.scheduler.dispatch:get_observation:64 - M45:   50.00 *   3.23 =  161.66
# 2020-06-16 16:46:36.856 | INFO     | panoptes.pocs.scheduler.dispatch:get_observation:72 - Best observation: HAT-P-30	Score: 669.88
# 2020-06-16 16:46:36.866 | INFO     | panoptes.pocs.scheduler.scheduler:current_observation:128 - Setting new observation to HAT-P-30: 120.0 s exposures in blocks of 10, minimum 60, priority 100
# 2020-06-16 16:46:50.205 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:46:50.210 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:50.218 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:46:51.264 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:46:51.266 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:46:51.271 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:46:51.275 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:46:51.278 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:47:16.037 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:47:16.040 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:47:16.044 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:47:16.049 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:47:16.053 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:47:16.057 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:47:16.065 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:47:17.274 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:47:17.282 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:47:17.288 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:47:17.297 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:47:17.302 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:47:36.777 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:47:36.788 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:47:36.806 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:47:36.814 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:47:36.823 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:47:36.827 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:47:36.837 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:47:38.316 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:47:38.321 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:47:38.330 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:47:38.335 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:47:38.340 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds

# %%
pocs.observatory.scheduler.observations
# Out:
# {'Kepler 488': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e5a10280>,
#  'Kepler 1100': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec15ef40>,
#  'KIC 8462852': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e65212b0>,
#  'HD 23630': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e5a29460>,
#  'HD 189733': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec195d60>,
#  'HD 209458': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec1794f0>,
#  'Wasp 140': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec179cd0>,
#  'Wasp 104': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e651eac0>,
#  'Wasp 44': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec1a0340>,
#  'Wasp 2': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec1a00d0>,
#  'Wasp 24': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec16c670>,
#  'Wasp 77': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec195280>,
#  'Wasp 33': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec16f580>,
#  'Wasp 43': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec1aae80>,
#  'Wasp 36': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e5a37be0>,
#  'Wasp 11': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e5a29580>,
#  'Wasp 35': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e651e3a0>,
#  'HAT-P-20': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec1955b0>,
#  'Qatar-1': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e65b92e0>,
#  'Qatar-2': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec1b92b0>,
#  'Tres 3': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec101520>,
#  'EPIC-211089792': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec15ea60>,
#  'HAT-P-1': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec16fc10>,
#  'HAT-P-12': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec1b98e0>,
#  'HAT-P-19': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec16c4c0>,
#  'HAT-P-30': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec16f490>,
#  'HAT-P-36': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec1956d0>,
#  'HAT-P-37': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e6521b50>,
#  'M42': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec1797c0>,
#  'M44': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec16c160>,
#  'M45': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e5a295b0>,
#  'M5': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec179700>,
#  'CoRoT-18': <panoptes.pocs.scheduler.observation.Observation at 0x7f87ec1794c0>,
#  'Super Grav Wave Event': <panoptes.pocs.scheduler.observation.Observation at 0x7f87e6582a60>}
# 2020-06-16 16:47:51.347 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:47:51.351 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:47:51.358 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:47:52.306 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:47:52.311 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:47:52.316 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:47:52.325 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:47:52.331 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:48:17.377 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:48:17.401 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:48:17.414 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:48:17.426 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:48:17.431 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:48:17.441 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:48:17.451 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:48:19.104 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:48:19.109 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:48:19.121 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:48:19.127 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:48:19.133 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:48:38.410 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:48:38.419 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:48:38.430 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:48:38.442 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:48:38.446 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:48:38.453 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:48:38.462 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:48:39.576 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:48:39.580 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:48:39.585 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:48:39.591 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:48:39.594 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:48:52.403 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:48:52.407 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:48:52.412 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:48:53.185 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:48:53.188 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:48:53.192 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:48:53.199 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:48:53.202 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:49:19.196 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:49:19.200 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:49:19.206 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:49:19.211 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:49:19.214 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:49:19.219 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:49:19.226 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:49:20.115 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:49:20.117 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:49:20.123 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:49:20.129 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:49:20.134 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:49:39.663 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:49:39.668 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:49:39.674 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:49:39.683 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:49:39.690 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:49:39.700 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:49:39.721 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:49:40.768 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:49:40.771 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:49:40.777 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:49:40.781 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:49:40.792 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:49:53.277 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:49:53.286 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:49:53.294 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:49:54.127 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:49:54.129 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:49:54.133 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:49:54.144 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:49:54.148 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:50:20.199 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:50:20.203 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:50:20.210 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:50:20.222 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:50:20.228 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:50:20.233 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:50:20.252 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:50:20.983 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:50:20.987 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:50:20.992 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:50:20.999 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:50:21.005 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:50:40.850 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:50:40.853 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:50:40.859 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:50:40.867 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:50:40.872 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:50:40.878 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:50:40.888 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:50:41.939 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:50:41.944 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:50:41.947 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:50:41.951 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:50:41.955 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:50:54.216 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:50:54.222 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:50:54.226 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:50:55.031 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:50:55.035 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:50:55.040 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:50:55.043 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:50:55.051 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:51:21.078 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:51:21.085 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:51:21.098 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:51:21.108 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:51:21.116 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:51:21.124 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:51:21.136 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:51:21.845 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:51:21.848 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:51:21.851 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:51:21.856 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:51:21.859 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:51:42.023 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:51:42.027 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:51:42.032 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:51:42.039 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:51:42.052 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:51:42.058 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:51:42.074 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:51:42.917 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:51:42.920 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:51:42.926 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:51:42.930 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:51:42.934 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:51:55.116 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:51:55.124 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:51:55.131 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:51:56.096 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:51:56.099 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:51:56.104 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:51:56.108 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:51:56.114 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:52:21.920 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:52:21.925 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:52:21.932 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:52:21.937 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:52:21.942 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:52:21.947 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:52:21.955 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:52:22.666 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:52:22.669 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:52:22.673 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:52:22.678 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:52:22.683 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:52:43.010 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:52:43.017 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:52:43.023 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:52:43.030 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:52:43.040 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:52:43.046 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:52:43.061 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:52:44.645 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:52:44.651 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:52:44.658 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:52:44.669 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:52:44.676 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:52:56.182 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:52:56.187 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:52:56.201 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:52:57.181 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:52:57.184 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:52:57.188 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:52:57.192 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:52:57.195 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:53:22.751 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:53:22.756 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:53:22.764 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:53:22.769 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:53:22.776 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:53:22.783 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:53:22.797 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:53:23.892 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:53:23.896 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:53:23.900 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:53:23.904 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:53:23.911 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:53:44.743 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:53:44.748 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:53:44.756 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:53:44.763 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:53:44.775 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:53:44.780 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:53:44.789 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:53:45.753 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:53:45.756 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:53:45.760 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:53:45.764 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:53:45.767 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:53:57.266 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:53:57.273 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:53:57.283 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:53:57.997 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:53:58.000 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:53:58.004 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:53:58.011 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:53:58.014 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:54:23.975 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:54:23.979 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:54:23.986 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:54:23.995 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:54:24.004 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:54:24.009 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:54:24.022 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:54:24.908 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:54:24.911 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:54:24.916 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:54:24.921 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:54:24.925 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:54:45.840 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:54:45.847 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:54:45.851 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:54:45.856 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:54:45.863 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:54:45.871 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:54:45.884 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:54:46.687 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:54:46.690 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:54:46.695 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:54:46.699 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:54:46.702 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:54:58.086 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:54:58.089 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:54:58.097 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:54:58.896 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:54:58.898 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:54:58.902 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:54:58.907 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:54:58.911 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:55:25.004 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:55:25.011 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:55:25.032 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:55:25.043 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:55:25.051 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:55:25.061 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:55:25.076 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:55:26.820 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:55:26.824 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:55:26.830 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:55:26.834 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:55:26.839 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:55:46.773 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:55:46.781 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:55:46.786 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:55:46.792 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:55:46.796 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:55:46.800 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:55:46.806 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:55:47.508 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:55:47.512 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:55:47.515 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:55:47.519 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:55:47.522 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:55:58.981 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:55:58.989 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:55:58.998 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:56:00.136 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:56:00.143 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:56:00.150 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:56:00.157 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:56:00.164 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:56:26.906 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:56:26.911 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:56:26.918 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:56:26.925 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:56:26.932 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:56:26.939 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:56:26.949 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:56:27.726 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:56:27.728 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:56:27.731 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:56:27.734 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:56:27.747 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:56:47.590 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:56:47.595 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:56:47.602 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:56:47.611 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:56:47.619 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:56:47.628 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:56:47.646 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:56:48.757 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:56:48.762 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:56:48.767 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:56:48.776 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:56:48.782 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:57:00.235 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:57:00.265 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:57:00.271 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:57:01.524 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:57:01.527 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:57:01.543 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:57:01.548 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:57:01.552 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:57:27.806 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:57:27.810 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:57:27.818 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:57:27.824 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:57:27.832 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:57:27.839 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:57:27.850 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:57:28.596 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:57:28.599 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:57:28.606 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:57:28.614 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:57:28.627 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:57:48.855 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:57:48.867 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:57:48.882 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:57:48.897 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:57:48.907 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:57:48.914 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:57:48.921 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:57:50.160 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:57:50.163 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:57:50.168 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:57:50.173 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:57:50.177 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:58:01.621 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:58:01.628 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:58:01.634 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:58:02.419 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:58:02.422 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:58:02.426 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:58:02.432 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:58:02.436 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 16:58:28.698 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:58:28.711 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:58:28.722 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:58:28.732 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:58:28.738 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:58:28.752 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:58:28.763 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:58:30.490 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:58:30.502 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:58:30.516 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:58:30.523 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:58:30.542 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.98 seconds
# 2020-06-16 16:58:50.246 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:58:50.255 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:58:50.261 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:58:50.269 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:58:50.275 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:58:50.281 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:58:50.296 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:58:52.037 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:58:52.049 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:58:52.062 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:58:52.069 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:58:52.079 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:59:02.504 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:59:02.511 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:59:02.517 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:59:04.287 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:59:04.293 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:59:04.298 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:59:04.304 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:59:04.310 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:59:30.602 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:59:30.608 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:59:30.613 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:59:30.619 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:59:30.627 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:59:30.631 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:59:30.638 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:59:31.318 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:59:31.321 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:59:31.326 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:59:31.329 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:59:31.338 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 16:59:52.154 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 16:59:52.159 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:59:52.164 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 16:59:52.173 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 16:59:52.180 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 16:59:52.190 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 16:59:52.199 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 16:59:53.004 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 16:59:53.007 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 16:59:53.011 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 16:59:53.015 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 16:59:53.020 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:00:04.377 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:00:04.381 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:00:04.386 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:00:05.122 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:00:05.126 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:00:05.130 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:00:05.134 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:00:05.138 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:00:31.400 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:00:31.403 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:00:31.411 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:00:31.418 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 17:00:31.424 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 17:00:31.431 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 17:00:31.442 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 17:00:32.103 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:00:32.106 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:00:32.111 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:00:32.115 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:00:32.122 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 59.99 seconds
# 2020-06-16 17:00:53.088 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:00:53.092 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:00:53.100 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:00:53.107 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# ...
#
# 2020-06-16 17:06:35.352 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:06:35.353 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:06:35.357 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:06:35.359 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:06:56.709 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:06:56.710 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:06:56.711 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:06:56.713 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 17:06:56.714 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 17:06:56.716 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 17:06:56.718 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 17:06:56.936 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:06:56.937 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:06:56.941 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:06:56.943 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:06:56.944 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:07:08.480 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:07:08.481 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:07:08.482 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:07:08.712 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:07:08.715 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:07:08.716 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:07:08.718 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:07:08.719 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:07:35.411 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:07:35.412 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:07:35.414 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:07:35.416 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 17:07:35.418 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 17:07:35.419 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 17:07:35.422 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 17:07:35.738 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:07:35.739 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:07:35.740 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:07:35.742 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:07:35.743 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:07:57.003 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:07:57.004 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:07:57.006 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:07:57.008 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 17:07:57.009 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 17:07:57.011 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 17:07:57.014 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 17:07:57.337 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:07:57.338 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:07:57.341 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:07:57.344 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:07:57.347 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:08:08.782 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:08:08.783 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:08:08.785 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:08:09.068 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:08:09.070 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:08:09.073 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:08:09.079 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:08:09.083 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:08:35.809 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:08:35.815 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:08:35.819 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:08:35.822 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 17:08:35.825 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 17:08:35.828 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 17:08:35.832 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 17:08:36.394 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:08:36.395 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:08:36.396 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:08:36.397 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:08:36.399 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:08:57.409 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:08:57.411 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:08:57.414 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:08:57.417 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 17:08:57.420 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 17:08:57.423 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 17:08:57.425 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 17:08:58.088 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:08:58.091 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:08:58.094 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:08:58.098 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:08:58.102 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:09:09.145 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:09:09.148 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:09:09.151 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:09:09.449 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:09:09.450 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:09:09.451 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:09:09.452 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:09:09.453 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:09:36.445 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:09:36.446 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:09:36.447 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:09:36.449 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 17:09:36.450 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 17:09:36.451 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 17:09:36.453 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 17:09:36.694 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:09:36.695 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:09:36.696 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:09:36.697 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:09:36.699 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:09:58.164 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:09:58.165 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:09:58.166 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:09:58.168 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 17:09:58.169 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 17:09:58.170 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 17:09:58.172 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 17:09:58.422 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:09:58.422 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:09:58.424 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:09:58.425 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:09:58.427 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:10:09.516 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:10:09.518 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:10:09.521 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:10:09.773 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:10:09.775 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:10:09.776 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:10:09.778 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:10:09.779 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:10:36.759 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:10:36.761 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:10:36.762 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:10:36.763 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 17:10:36.764 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 17:10:36.766 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 17:10:36.768 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 17:10:36.982 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:10:36.983 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:10:36.984 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:10:36.986 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:10:36.987 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
# 2020-06-16 17:10:58.473 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config true
#
# 2020-06-16 17:10:58.473 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:10:58.474 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=pocs.CONNECTED: config_entry=True
# 2020-06-16 17:10:58.476 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Scheduler not present
# 2020-06-16 17:10:58.477 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Cameras not present
# 2020-06-16 17:10:58.479 | WARNING  | panoptes.pocs.observatory:can_observe:178 - Mount not present
# 2020-06-16 17:10:58.481 | INFO     | panoptes.pocs.observatory:current_observation:137 - Scheduler not present, cannot get current observation.
# 2020-06-16 17:10:58.694 | DEBUG    | panoptes.utils.config.client:get_config:71 - Received config 60
#
# 2020-06-16 17:10:58.695 | DEBUG    | panoptes.utils.config.client:get_config:73 - Parsing config results
# 2020-06-16 17:10:58.696 | INFO     | panoptes.utils.config.client:get_config:82 - Config key=status_check_interval: config_entry=60
# 2020-06-16 17:10:58.698 | DEBUG    | panoptes.utils.time:restart:165 - Restarting Timer (blocking) 60.00/60.00
# 2020-06-16 17:10:58.701 | DEBUG    | panoptes.utils.time:sleep:186 - Sleeping for 60.00 seconds
